# %%
import pydicom as dicom
import matplotlib.pyplot as plt
from pydicom.data import get_testdata_file

# %%
x = dicom.dcmread("EE00D340")
plt.imshow(x.pixel_array)

# %%
x
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 166
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.46.670589.11.0.4.1996082307380006
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.3.46.670589.17
# (0002, 0013) Implementation Version Name         SH: 'ARC_CONVERT'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'OTHER', 'R', 'IR']
# (0008, 0012) Instance Creation Date              DA: '19960823'
# (0008, 0013) Instance Creation Time              TM: '093801'
# (0008, 0014) Instance Creator UID                UI: 1.3.46.670589.11.0.5
# ...

# %%
import dicom2jpg

# %%
dicom_img_01 = "EE00D340"

# %%
dicom2jpg.dicom2jpg(dicom_img_01, target_root="saved/")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-28-1efdb980022d> in <module>
# ----> 1 dicom2jpg.dicom2jpg(dicom_img_01, target_root="saved/")
#
# ~\anaconda3\lib\site-packages\dicom2jpg\__init__.py in dicom2jpg(origin, target_root, anonymous, multiprocessing)
#      48     default target root folder is the root of origin file
#      49     """
# ---> 50     return _dicom_convertor(origin, target_root, filetype='jpg',
#      51                             multiprocessing=multiprocessing,
#      52                             anonymous=anonymous)
#
# ~\anaconda3\lib\site-packages\dicom2jpg\utils.py in _dicom_convertor(origin, target_root, filetype, anonymous, multiprocessing)
#     237
#     238     # get root folder (as target_root) and dicom_file_list
# --> 239     target_root, dicom_file_list = _get_root_get_dicom_file_list(origin, target_root)
#     240
# ...
